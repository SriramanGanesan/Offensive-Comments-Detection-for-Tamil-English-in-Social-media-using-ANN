# %%
# Importing Essential Packages
import numpy as np
import tensorflow as tf
import pandas as pd

# Importing Essential Functions from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# Importing Neural Networksfunctions from Tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Various Classifiers to Compare Accuracy
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier

# Label Assignmnent
languages = ['eng_tamil']
label = {
    '0' : 'homophobic',
    '1' : 'normal',
    '2' : 'transphobic'
}
data = {}

# Load datasets
for lang in languages:
    data[lang] = {
        'train': pd.read_csv(f"/content/eng_tam_train_prepro_nonaug.csv"),
        'test': pd.read_csv(f"/content/eng_tam_test_prepro_nonaug.csv")
    }

# Encode labels
Label_Encoder = LabelEncoder()
for lang in languages:
    data[lang]['train']['label'] = Label_Encoder.fit_transform(data[lang]['train']['label'])
    data[lang]['test']['label'] = Label_Encoder.transform(data[lang]['test']['label'])

# Feature extraction
vectorizer = TfidfVectorizer(max_features=5000)
X_Train_Data = vectorizer.fit_transform(data[lang]['train']['text'])
X_Test_Data = vectorizer.transform(data[lang]['test']['text'])
Y_Train_Data = data[lang]['train']['label']
Y_Test_Data = data[lang]['test']['label']

# Build the ANN model with increased hidden layers and dropout
model = Sequential([
    Dense(512, activation = 'relu', input_shape=(X_Train_Data.shape[1],)),
    Dropout(0.5),
    Dense(256, activation = 'relu'),
    Dropout(0.5),
    Dense(128, activation = 'relu'),
    Dropout(0.5),
    Dense(64, activation = 'relu'),
    Dropout(0.5),
    Dense(3, activation = 'softmax')
])

# Compile the model
model.compile(optimizer=Adam(lr = 0.001),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

# Train the model
history = model.fit(X_Train_Data.toarray(),Y_Train_Data, epochs=25, batch_size=32, validation_split=0.1)

# Evaluate the model
Y_Pred_ANN = np.argmax(model.predict(X_Test_Data.toarray()), axis=-1)
print("ANN Confusion Matrix:")
print(confusion_matrix(Y_Test_Data, Y_Pred_ANN))
print("\n ANN Classification Report:")
print(classification_report(Y_Test_Data, Y_Pred_ANN))
print("-"*50)

knn = KNeighborsClassifier(n_neighbors=10)  # You can adjust the number of neighbors (k) as needed
knn.fit(X_Train_Data,Y_Train_Data)

# Predict and evaluate the model
Y_Pred_KNN = knn.predict(X_Test_Data)
print("KNN Confusion Matrix:")
print(confusion_matrix(Y_Test_Data, Y_Pred_KNN))
print("\n KNN Classification Report:")
print(classification_report(Y_Test_Data, Y_Pred_KNN))
print("-"*50)


def Train_and_Evaluate(X_Train_Data, Y_Train_Data, X_Test_Data, Y_Test_Datat, model, model_name):
    # Train the model
    model.fit(X_Train_Data, Y_Train_Data)

    # Predict on the test set
    y_pred = model.predict(X_Test_Data)

    # Print the confusion matrix
    Confusion_Matrix = confusion_matrix(Y_Test_Data, y_pred)
    print(f'{model_name} Confusion Matrix:')
    print(Confusion_Matrix)
    print()

    # Print the classification report
    Classification_Report = classification_report(Y_Test_Data, y_pred)
    print(f'{model_name} Classification Report:')
    print(Classification_Report)
    print()



for lang in languages:
    #X_train, X_test = extract_features(data[lang]['train']['Text'], data[lang]['test']['Text'])
    # SVM
    Support_Vector_Macine = SVC(kernel='linear', C=1)
    Train_and_Evaluate(X_Train_Data, data[lang]['train']['label'], X_Test_Data, data[lang]['test']['label'], Support_Vector_Macine, 'Support Vector Machine')
    print("-"*50)


    # Logistic Regression
    Logistic_Regression = LogisticRegression(max_iter=1000)
    Train_and_Evaluate(X_Train_Data, data[lang]['train']['label'], X_Test_Data, data[lang]['test']['label'], Logistic_Regression, 'Logistic Regression')
    print("-"*50)


    # Decision Tree
    DecisionTree = DecisionTreeClassifier()
    Train_and_Evaluate(X_Train_Data, data[lang]['train']['label'], X_Test_Data, data[lang]['test']['label'], DecisionTree, 'Decision Tree')
    print("-"*50)


    # Random Forest
    Random_Forest = RandomForestClassifier()
    Train_and_Evaluate(X_Train_Data, data[lang]['train']['label'], X_Test_Data, data[lang]['test']['label'], Random_Forest, 'Random Forest')
    print("-"*50)


    # Naive Bayes
    X_train_dense = X_Train_Data.toarray()
    X_test_dense = X_Test_Data.toarray()
    Naive_Bayes = GaussianNB()
    Train_and_Evaluate(X_train_dense, data[lang]['train']['label'], X_test_dense, data[lang]['test']['label'], Naive_Bayes, 'Naive Bayes')
    print("-"*50)


    # GradientBoosting
    Gradient_Boosting = GradientBoostingClassifier()
    Train_and_Evaluate(X_Train_Data, data[lang]['train']['label'], X_Test_Data, data[lang]['test']['label'],Gradient_Boosting , 'Gradient Boosting')
    print("-"*50)


    # Multi Layer Perceptron
    MLP = MLPClassifier()
    Train_and_Evaluate(X_Train_Data, data[lang]['train']['label'], X_Test_Data, data[lang]['test']['label'], MLP, 'Multilayer Perceptron')
    print("-"*50)


    # XGBoost
    XGB = XGBClassifier()
    Train_and_Evaluate(X_Train_Data, data[lang]['train']['label'], X_Test_Data, data[lang]['test']['label'], XGB, 'XGBoost')
    print("-"*50)


# Iterate through the test dataset, print text and predictions
for i in range(len(data[lang]['test']['text'])):
    text = data[lang]['test']['text'].iloc[i]
    true_label = Label_Encoder.inverse_transform([Y_Test_Data[i]])[0]
    predicted_label = Label_Encoder.inverse_transform([Y_Pred_ANN[i]])[0]

    if true_label == 0:
      true_label = "Homophobic"
    elif true_label == 1:
      true_label = "Normal"
    else:
      true_label = "Transphobic"

    if predicted_label == 0:
      predicted_label = "Homophobic"
    elif predicted_label == 1:
      predicted_label = "Normal"
    else:
      predicted_label = "Transphobic"

    print(f"Text: {text}")
    print(f"True Label: {true_label}")
    print(f"Predicted Label: {predicted_label}")
    print()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/25
# 109/109 [==============================] - 5s 37ms/step - loss: 0.5177 - accuracy: 0.8673 - val_loss: 0.3245 - val_accuracy: 0.8966
# Epoch 2/25
# 109/109 [==============================] - 4s 41ms/step - loss: 0.2994 - accuracy: 0.8898 - val_loss: 0.3257 - val_accuracy: 0.8966
# Epoch 3/25
# 109/109 [==============================] - 4s 35ms/step - loss: 0.2061 - accuracy: 0.8961 - val_loss: 0.3656 - val_accuracy: 0.8915
# Epoch 4/25
# 109/109 [==============================] - 4s 34ms/step - loss: 0.1511 - accuracy: 0.9421 - val_loss: 0.5515 - val_accuracy: 0.8863
# Epoch 5/25
# 109/109 [==============================] - 4s 38ms/step - loss: 0.1102 - accuracy: 0.9577 - val_loss: 0.6379 - val_accuracy: 0.8786
# Epoch 6/25
# 109/109 [==============================] - 4s 38ms/step - loss: 0.0915 - accuracy: 0.9600 - val_loss: 0.6761 - val_accuracy: 0.8656
# Epoch 7/25
# 109/109 [==============================] - 4s 35ms/step - loss: 0.0702 - accuracy: 0.9626 - val_loss: 0.7577 - val_accuracy: 0.8760
# Epoch 8/25
# 109/109 [==============================] - 4s 37ms/step - loss: 0.0534 - accuracy: 0.9649 - val_loss: 0.7343 - val_accuracy: 0.8760
# Epoch 9/25
# 109/109 [==============================] - 5s 43ms/step - loss: 0.0431 - accuracy: 0.9830 - val_loss: 0.8963 - val_accuracy: 0.8837
# Epoch 10/25
# 109/109 [==============================] - 4s 37ms/step - loss: 0.0343 - accuracy: 0.9891 - val_loss: 0.9657 - val_accuracy: 0.8863
# Epoch 11/25
# 109/109 [==============================] - 4s 37ms/step - loss: 0.0341 - accuracy: 0.9885 - val_loss: 0.9524 - val_accuracy: 0.8915
# Epoch 12/25
# 109/109 [==============================] - 5s 43ms/step - loss: 0.0221 - accuracy: 0.9948 - val_loss: 1.0042 - val_accuracy: 0.8915
# Epoch 13/25
# 109/109 [==============================] - 4s 35ms/step - loss: 0.0210 - accuracy: 0.9957 - val_loss: 0.9117 - val_accuracy: 0.9018
# Epoch 14/25
# 109/109 [==============================] - 4s 36ms/step - loss: 0.0174 - accuracy: 0.9957 - val_loss: 0.8898 - val_accuracy: 0.8941
# Epoch 15/25
# 109/109 [==============================] - 5s 42ms/step - loss: 0.0134 - accuracy: 0.9968 - val_loss: 1.0224 - val_accuracy: 0.8915
# Epoch 16/25
# 109/109 [==============================] - 4s 35ms/step - loss: 0.0116 - accuracy: 0.9980 - val_loss: 0.9664 - val_accuracy: 0.8915
# Epoch 17/25
# 109/109 [==============================] - 4s 36ms/step - loss: 0.0114 - accuracy: 0.9974 - val_loss: 0.9428 - val_accuracy: 0.8966
# Epoch 18/25
# 109/109 [==============================] - 5s 43ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 1.0317 - val_accuracy: 0.8915
# Epoch 19/25
# 109/109 [==============================] - 4s 35ms/step - loss: 0.0063 - accuracy: 0.9986 - val_loss: 1.1011 - val_accuracy: 0.8889
# Epoch 20/25
# 109/109 [==============================] - 4s 36ms/step - loss: 0.0096 - accuracy: 0.9974 - val_loss: 0.9933 - val_accuracy: 0.8889
# Epoch 21/25
# 109/109 [==============================] - 5s 43ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 1.0855 - val_accuracy: 0.8863
# Epoch 22/25
# 109/109 [==============================] - 4s 35ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 1.1098 - val_accuracy: 0.8889
# Epoch 23/25
# 109/109 [==============================] - 4s 36ms/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 1.0787 - val_accuracy: 0.8863
# Epoch 24/25
# 109/109 [==============================] - 5s 43ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 1.1138 - val_accuracy: 0.8863
# Epoch 25/25
# 109/109 [==============================] - 4s 35ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.9841 - val_accuracy: 0.8915
# 38/38 [==============================] - 0s 7ms/step
# ANN Confusion Matrix:
# [[  21   61    6]
#  [  36 1017   32]
#  [   4   18   12]]
#
#  ANN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.34      0.24      0.28        88
#            1       0.93      0.94      0.93      1085
#            2       0.24      0.35      0.29        34
#
#     accuracy                           0.87      1207
#    macro avg       0.50      0.51      0.50      1207
# weighted avg       0.87      0.87      0.87      1207
#
# --------------------------------------------------
# KNN Confusion Matrix:
# [[   0   88    0]
#  [   0 1085    0]
#  [   0   34    0]]
#
#  KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        88
#            1       0.90      1.00      0.95      1085
#            2       0.00      0.00      0.00        34
#
#     accuracy                           0.90      1207
#    macro avg       0.30      0.33      0.32      1207
# weighted avg       0.81      0.90      0.85      1207
#
# --------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Support Vector Machine Confusion Matrix:
# [[   8   80    0]
#  [   7 1078    0]
#  [   3   29    2]]
#
# Support Vector Machine Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.44      0.09      0.15        88
#            1       0.91      0.99      0.95      1085
#            2       1.00      0.06      0.11        34
#
#     accuracy                           0.90      1207
#    macro avg       0.78      0.38      0.40      1207
# weighted avg       0.88      0.90      0.87      1207
#
#
# --------------------------------------------------
# Logistic Regression Confusion Matrix:
# [[   4   84    0]
#  [   2 1083    0]
#  [   1   32    1]]
#
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.05      0.08        88
#            1       0.90      1.00      0.95      1085
#            2       1.00      0.03      0.06        34
#
#     accuracy                           0.90      1207
#    macro avg       0.82      0.36      0.36      1207
# weighted avg       0.88      0.90      0.86      1207
#
#
# --------------------------------------------------
# Decision Tree Confusion Matrix:
# [[  22   60    6]
#  [  54 1007   24]
#  [   3   27    4]]
#
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.28      0.25      0.26        88
#            1       0.92      0.93      0.92      1085
#            2       0.12      0.12      0.12        34
#
#     accuracy                           0.86      1207
#    macro avg       0.44      0.43      0.44      1207
# weighted avg       0.85      0.86      0.85      1207
#
#
# --------------------------------------------------
# Random Forest Confusion Matrix:
# [[   3   83    2]
#  [   7 1077    1]
#  [   1   30    3]]
#
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.27      0.03      0.06        88
#            1       0.91      0.99      0.95      1085
#            2       0.50      0.09      0.15        34
#
#     accuracy                           0.90      1207
#    macro avg       0.56      0.37      0.39      1207
# weighted avg       0.85      0.90      0.86      1207
#
#
# --------------------------------------------------
# Naive Bayes Confusion Matrix:
# [[ 28  57   3]
#  [179 863  43]
#  [  7  17  10]]
#
# Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.13      0.32      0.19        88
#            1       0.92      0.80      0.85      1085
#            2       0.18      0.29      0.22        34
#
#     accuracy                           0.75      1207
#    macro avg       0.41      0.47      0.42      1207
# weighted avg       0.84      0.75      0.79      1207
#
#
# --------------------------------------------------
# Gradient Boosting Confusion Matrix:
# [[   7   78    3]
#  [   7 1074    4]
#  [   1   29    4]]
#
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.08      0.14        88
#            1       0.91      0.99      0.95      1085
#            2       0.36      0.12      0.18        34
#
#     accuracy                           0.90      1207
#    macro avg       0.58      0.40      0.42      1207
# weighted avg       0.86      0.90      0.87      1207
#
#
# --------------------------------------------------
# Multilayer Perceptron Confusion Matrix:
# [[  27   58    3]
#  [  46 1022   17]
#  [   6   19    9]]
#
# Multilayer Perceptron Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.34      0.31      0.32        88
#            1       0.93      0.94      0.94      1085
#            2       0.31      0.26      0.29        34
#
#     accuracy                           0.88      1207
#    macro avg       0.53      0.50      0.51      1207
# weighted avg       0.87      0.88      0.87      1207
#
#
# --------------------------------------------------
# XGBoost Confusion Matrix:
# [[  11   76    1]
#  [  17 1063    5]
#  [   2   28    4]]
#
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.37      0.12      0.19        88
#            1       0.91      0.98      0.94      1085
#            2       0.40      0.12      0.18        34
#
#     accuracy                           0.89      1207
#    macro avg       0.56      0.41      0.44      1207
# weighted avg       0.86      0.89      0.87      1207
#
#
# --------------------------------------------------
# Text: Ivlo therinjum kadaisi la saga manushana dead body koodayum animals koodayum compare panniteenga!  OK_hand  OK_hand  Arumai ji!
# True Label: Normal
# Predicted Label: Normal
#
# Text: Neenga gay va
# True Label: Normal
# Predicted Label: Normal
#
# Text: 3.42 sec ultimate  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro endha oru nega soluga bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super Anda akkavukku enathu anbarntha vaalthukkal thirunangai vaalga  folded_hands  folded_hands  folded_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Aluthuta da thambi loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: I want permanent lifepartner
# True Label: Normal
# Predicted Label: Normal
#
# Text: Yogesh Waran Hey nee 9 taane  winking_face_with_tongue  grinning_squinting_face
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Kolai Seibavan Kooda avanukku oru niyayam vaithiruppaan. Adhanaal avan seivadhu sari illai.
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: I love you akka
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ala vachitiyae nanba  downcast_face_with_sweat  loudly_crying_face  loudly_crying_face  loudly_crying_face  broken_heart
# True Label: Normal
# Predicted Label: Normal
#
# Text: Tamil nadu Bus Metro ItRain...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Serupa alla ADI naramunda
# True Label: Transphobic
# Predicted Label: Normal
#
# Text: Semathaya sollu irukinga malini...super...en support ungaluku irukku
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nee nalla pesura akka
# True Label: Normal
# Predicted Label: Normal
#
# Text: Semah pa 2015 layae intha Mari subject eaduthu romba thairiyamah pannirukinga, superr ah irruki film. Actor kuda romba Nala panirukanga  clapping_hands  clapping_hands  clapping_hands  clapping_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: 52 likes tha na vj face kavathu like pannunga da ...i like u baby...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Life pathi ennanu theriyama pesuthu antha ponnu.......first kannadi ethukku potturukku? Thaanga mudilada.....o
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Na bisexual tan...  pensive_face  Enaku gay's  um pudikm... Ana Enku Epovara true best friend yarumilla  pensive_face ...Ellarum vitu poraga Rombha kastama Iruku...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Mohan kumar yah well said
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super akka neenga nala erupinga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Time irunta linenukku vanga.OK va machi.
# True Label: Normal
# Predicted Label: Normal
#
# Text: swetha k ,enga vitulaya freedom nu solranga,illa unna Mari nadakurangala?idu kuda thetiyama solra panni nee thane?
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Bro neega serious aa vera lvl face_blowing_a_kiss  face_blowing_a_kiss
# True Label: Normal
# Predicted Label: Normal
#
# Text: prasan kumar  but aana unmai dhan brooo na like potean
# True Label: Normal
# Predicted Label: Normal
#
# Text: atellaam onnume ellai.
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Bro Naan Ethum Thappa Sollala Ninga Thappa Puringukittinga Appadi Naan Yethavathu Thappa Pesirunthaa.. Sorry Ennai Maniichurungaa folded_hands  folded_hands  folded_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Paul Vijay  nenga soldra padi Bible la Ella people um love pananu Ellaru Inga samam, love is me(god) apdi nu Jesus solirukaru....then Ella uyirgalilum homosexuals iruku proof venum Nah simple,google la poi parunga....
# True Label: Normal
# Predicted Label: Normal
#
# Text: Pennukku undaana entha oru arikuriyum eva kitta onnum illaiye ......Nan unkitta nerla pesanum ...WHO ,america sonna evanunga vetha vakku nu nenaichu kiraangaa evan da america avan sollita ellam correct ..Evana kettalum america va sollitanga ...Nu ponga da dei ...
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Broooo super bro nenga dhan bro gethu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Love u Amma  face_blowing_a_kiss  smiling_face_with_open_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Amma neenga romba azhaga irrukinga .pathumasam somandada dha pene thayaval ana neenga somakamale thayavinga ongala ammanu kupudravanga ellorukum . Neenga ammanuku samamanavanga amma  folded_hands  folded_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: wow  fire  fire  fire  wow
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super super super face_with_tears_of_joy  rolling_on_the_floor_laughing  face_with_tears_of_joy  rolling_on_the_floor_laughing  face_with_tears_of_joy
# True Label: Normal
# Predicted Label: Normal
#
# Text: Kadavul illanu yaarum sola mudiyaathu nala manasu ullavunga Kadavul soluvanga athula intha akka (amma)vum Kadavul than ninga kandipa 100 yrs nala erukanum akka (amma )
# True Label: Normal
# Predicted Label: Normal
#
# Text: Yov part 2 yeppoyaa varum
# True Label: Normal
# Predicted Label: Normal
#
# Text: Rumba kastma iruku.....oru public places poga mudiyala
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Babussalam Riyas   red_heart  red_heart  red_heart  beaming_face_with_smiling_eyes
# True Label: Normal
# Predicted Label: Normal
#
# Text: yena sex kaaga thirunangai ya erunthalum ok tha la
# True Label: Normal
# Predicted Label: Normal
#
# Text: ippati pesurathu vatikkai aki vittathu!!! itha kkurathu police la varamatanka
# True Label: Normal
# Predicted Label: Normal
#
# Text: Serpala adikanum......enga ponanulm ithuka tholla thanga mudila ...
# True Label: Transphobic
# Predicted Label: Normal
#
# Text: Anna! aka! sry ungala parata midila
# True Label: Normal
# Predicted Label: Normal
#
# Text: eva rajithu thunu oru nara naai kuda suthithu eruthavathana
# True Label: Normal
# Predicted Label: Transphobic
#
# Text: Super bro antha akkaku romba nalla manasu... pleading_face  pleading_face  thumbs_up  thumbs_up
# True Label: Normal
# Predicted Label: Normal
#
# Text: We are here for u sister  folded_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Inga kalyana panna ponnu kitaigama kastap paturanga nenga enada na leasbian gay nu ithu manitha kula aliyota arambam angry_face  angry_face  angry_face  angry_face  angry_face  angry_face  enraged_face  enraged_face  enraged_face
# True Label: Homophobic
# Predicted Label: Transphobic
#
# Text: Meera mithun super model
# True Label: Normal
# Predicted Label: Normal
#
# Text: Yen pa. Oruthar 2 per itha sonna sari. But India la lakhs kanakula gays lesbian irukaga. Ethiku intha mathri feelings varuthu nu parunga.
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ungaluku job
# True Label: Normal
# Predicted Label: Normal
#
# Text: G konjam Anna tower ku poi Paruga g avaga thola thagamudiyala
# True Label: Normal
# Predicted Label: Normal
#
# Text: Mohamed Frook Farook sarithaan perukku mattumthaan meesai ullukkula payammm
# True Label: Normal
# Predicted Label: Normal
#
# Text: God bless sister
# True Label: Normal
# Predicted Label: Normal
#
# Text: @vimal lal  poda Thevudiya Paiyaa
# True Label: Normal
# Predicted Label: Normal
#
# Text: msg panunga bro pesalm no call please
# True Label: Normal
# Predicted Label: Normal
#
# Text: po de komali...
# True Label: Normal
# Predicted Label: Normal
#
# Text: En kannula erudhu kanneer vandhuruchu,  idhu prank illa, unarvupooravamaana oru real life ah short film ah pannirukkega senmma  yaarune theriyaadha payya kanneer vaduchaanu andha thirunaggai akka dance pannaaga,  good human being super super super,  red_heart  red_heart  red_heart  red_heart  red_heart  red_heart  red_heart  red_heart  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon  heart_with_ribbon
# True Label: Normal
# Predicted Label: Normal
#
# Text: Galatta channel la ivanga interview link kudunga pls
# True Label: Normal
# Predicted Label: Normal
#
# Text: @G A U T I  adhuku pesama thaniya poidalam yeppo vachum occasionally poitu vandheengana endha problem um irukathu beaming_face_with_smiling_eyes
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ivangala onnum seiyama mudiyala, pothu idathula acingapaduthiruvanganu paiyanthu poogavendi irukku, kovappadavum mudiyala, Government than kandikkanum
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Priya Priya  Mm hii
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Kadhayalla Nijam  viluthuda gay koodhigala matamalayada poiduvinga neenga
# True Label: Homophobic
# Predicted Label: Homophobic
#
# Text: 0:42 la erukara ponnu KU ethuku support pandromne therla...aana summa English la pesitome... Atha kapathanome nu pesuthu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro sathiyama Solran super bro.. I got goosebumps bro..
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nanum niraya pannirukan
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Super prank thalaiva semma prank
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vishwa Hanu unga vittu pengalai vara sollu nan varen... adei ithula itherithu un buththi enananu... oruthar inoruthar ku support  panna anga freedom  nu pesi pirantha meniya vara solra thu..
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Sandy R  ne sunniya irundha Ena pundaya irundha Ena da thevadiyaluku porandha soothu nakki  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy  yara irundhalum ne sootha nakka porandha nakki paya dhana
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Avan than unga appan
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: enda ne poie IT la vela pakuravanta kekure satharana makkal ta kelu avan soluvan IT la vela pakuravan elame mutta payala than irupan
# True Label: Normal
# Predicted Label: Normal
#
# Text: Semma vedio bro  victory_hand   victory_hand   victory_hand
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Ayy Ar  wow appadiye vayileye adichi vidunga.fulla kudicci mudicciduren.semma tast  machi.enakkum  ippo viliaga pogutu dear.
# True Label: Normal
# Predicted Label: Normal
#
# Text: thu naayingala kadavul adhanalathan ungala ippadi padaitthu irukirar
# True Label: Transphobic
# Predicted Label: Normal
#
# Text: Ungala roomba pidechiruku sister ungaro attitude super sister
# True Label: Normal
# Predicted Label: Normal
#
# Text: Neenga romba azhaga irukinga sister
# True Label: Normal
# Predicted Label: Normal
#
# Text: Stay happy guys star-struck
# True Label: Normal
# Predicted Label: Normal
#
# Text: Thambi romba karutha pesuraru
# True Label: Normal
# Predicted Label: Normal
#
# Text: Poornima Gowtham moodikitu poo.. idhu avanga avanga choice, idhula thalayida evanukkum arugathai illa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ennada prank show serial  mathiri aaakittinga part 1 part 2
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vera level ..... clapping_hands  clapping_hands  clapping_hands  clapping_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Antha akka va nadu rottula aada vaikura pundai mavane
# True Label: Normal
# Predicted Label: Normal
#
# Text: ALBERT JULIAN nee manushan manushan mela dhan varum avanga aano penno.. inga kena thanama vandhu penathadha
# True Label: Normal
# Predicted Label: Normal
#
# Text: Neenga etha gavanikiringa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Anna super naa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Sema speech malani
# True Label: Normal
# Predicted Label: Normal
#
# Text: Intha maariye oru jenmam irukkunga
# True Label: Transphobic
# Predicted Label: Normal
#
# Text: Aduthavanga vaazhkaiyo unarchiyo baathikkatha entha oru vishayamum thappu illa. Heterosexual ah illa homosexual ah irukkanuma ndra oru thani patta manushanoda urimai, athanala vara nallathum kettathum avanga sambantha patta vishayam.... atha thappu seri nu ellam vimarsanam pannavo, classify pannavo yaarukumay urimai kedayathu. Ithellam namma ooru 'ellam therinja egambaram'ngaluku purinchikkara arivum illa, aethukkara manasum illa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Dai unknown yelllaam Evan da vj VA pottaaan
# True Label: Normal
# Predicted Label: Normal
#
# Text: Oru payan pirakum podhey ,unmaya porakuran vacchukoo.avan matha vanga pesuratha pathu ,avanga thappu naa than crct nu sonna yaru right nu neeungaley sollunga?
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Pewter Greefin  enna mapu vekame illama ipdie pesiputta
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro prang show panna ippa d pannanum bro part 2 eppo bro sollunga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Payanukum ponukumay unaku vithaysam therlayea da
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super bro  sad_but_relieved_face  sad_but_relieved_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: Sexual orientation pathina arivu konjam kuda ila.. Pachaya comment pana dha nee la layaku... Unga kootam dha da ulagatha nasamakuringa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Kuttyma Jaya ..... hehehehe ....
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super super super  OK_hand  thumbs_up
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ealu munu ealu  munu munu rendu ealu rendu zero aaru
# True Label: Normal
# Predicted Label: Transphobic
#
# Text: @P. Nagaraj _ 43  oru naaal nee roadla pogumbothu kundi la pooola uduvaaa vaangikoda thevidyaaa naaaye.... Elllame manasa poruthu thaaa.. Evano apdi porakaaala da emantha kooothi....
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Bro nanum unga video ku varalam ma bro I'm good comedy pannu ven  grinning_face  grinning_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: Really semma avaga feelingaum nama purejiganum really semma
# True Label: Normal
# Predicted Label: Normal
#
# Text: Neenga LGBT yw
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super nanba.nalla manasu Antha Akka ku smiling_face_with_halo  heart_with_ribbon
# True Label: Normal
# Predicted Label: Normal
#
# Text: ponga paa beach ku kuda poga mudila ,romance pannum bodhu correct ah vandhuranga  unamused_face chumma chumma eppadi tha pandranga edha kela alu illiya. loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: Haaaaaaaa Haaaaaaaa  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  face_with_tears_of_joy  rolling_on_the_floor_laughing  face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Shrinivasan Kannan  bro naa yenna solla vanthey naa....avanga independent naamaye (kindal pannanum)...& Avanga LA (avamaanam )padutha num ...Unga vittla eppdi nadanthaa ni ungalukku yenna sari yaa thonu tho atha pannu ga....mattravarkali( keli... kindal & tharkolaikku ) avanga LA utpaduthaa thinga nu thaa sollren....
# True Label: Normal
# Predicted Label: Normal
#
# Text: Hello Bro unga email id kudunga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Sontha amma than paiyana epti samathana paduthuvangalo apti pannanga antha akka  smiling_face_with_halo  smiling_face_with_halo
# True Label: Normal
# Predicted Label: Normal
#
# Text: Homosex koodiyana nee
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Murattu single kalyanamae vendam poga da
# True Label: Normal
# Predicted Label: Transphobic
#
# Text: ivalayellam olunga thalayala thatti valathuruntha nalla irukum
# True Label: Normal
# Predicted Label: Normal
#
# Text: I support you na USA la iruku inga na pathuruka pesiruka avangalukum baby la iruku avangalae pethukitanga egg donar mulayama pethukaranga . Husband and wife ah vida girl and girl super ah life ah vazharanga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Maduraila room podalama
# True Label: Normal
# Predicted Label: Transphobic
#
# Text: Girl LA vida alaga irukaga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Enda  ippadi panringa  ungalukku panam venum na poi Pichai edu illa na seththudu atha vittuttu en da avanga manasa kasta paduthuronga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Devudiyoda pu... Nakkaraku 500 , 1000 selavu pandra Aaambalainga....   thirunangaikaluku 10 rs kuduka avlo yosipanuga ....
# True Label: Normal
# Predicted Label: Normal
#
# Text: God bless you akka long life
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super bro  smiling_face_with_heart-eyes .ellarum antha ammagale thapa tha nenaikirange but ana nambala vida avanga neriya kastapatu,vazhikaye vazhidrange ana yarum avangala mathikarathile, normal makkaluku vara kastam persu illa, ana thirunagaigal tha samugathula romba kasta padrange please yarum antha ammakale kastapaduthathige folded_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Rajeswari Rajagopalan hai
# True Label: Normal
# Predicted Label: Normal
#
# Text: I support LGBTQ
# True Label: Normal
# Predicted Label: Normal
#
# Text: Thalai vanagguren amma...neenga pesiyadhu anaithum unmaiye
# True Label: Normal
# Predicted Label: Normal
#
# Text: Dei indha thadi madu enna anchoring nalla pandranu ivanaiye ella channel laiyum podringa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vailave mithikanum intha naigala.
# True Label: Transphobic
# Predicted Label: Normal
#
# Text: Unga  found san members add me
# True Label: Normal
# Predicted Label: Normal
#
# Text: Oru sila thirunangaikalal anaithu thirunangaikalukum  ketta paru...avanga vaiyuthu polappuku epdi pandranga pavam...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Anbu angathan iruku namma thedi pora ponnunga kitta suya nalam mattum than irukku  grinning_face_with_sweat
# True Label: Normal
# Predicted Label: Normal
#
# Text: Thank you :)
# True Label: Normal
# Predicted Label: Normal
#
# Text: jee, s En Ninga Apadiya sapduringa
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Ranjani Ranju  yarada sollura 10 pooluku poranthavanea
# True Label: Normal
# Predicted Label: Normal
#
# Text: Heart touching  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  loudly_crying_face  god bless you akkaaaaa I love you akkaa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ava vachilanu unala nirubika mudiyouma
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Worst human being
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: @Desi Gamer  aama crctdhaan.. naan non muslimaagave iruntu poreneh..
# True Label: Normal
# Predicted Label: Normal
#
# Text: @girubhakar T  Mr. White unga english purila.!
# True Label: Normal
# Predicted Label: Normal
#
# Text: Thirunangai akka iku nalla manasu itha paakum pothu kan kalangitan
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nanba, Na un kitta neraiya kelvi kekkanu Nanba @Malini
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super bro vara level art
# True Label: Normal
# Predicted Label: Normal
#
# Text: my name lathu endu sonnan
# True Label: Normal
# Predicted Label: Normal
#
# Text: yuro Well Said Bro!!!  thumbs_up_light_skin_tone  thumbs_up_light_skin_tone  thumbs_up_light_skin_tone
# True Label: Normal
# Predicted Label: Normal
#
# Text: Unggallukkum .....thirunanggaiggalukkum .....enna vithiyasam ..........???¿?
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Podi sex paithiyam...  Periya thiyagi maathri pesura...  Iyarkai (nature)  ku against ah vaalura oru maangketta vaalkaiya vaalndhu asingam pannitu periya pudungi maathri pesura..  Un amma va kuda vida maata pola...  Sex veri pudicha moodhevi...  Kevalam...
# True Label: Homophobic
# Predicted Label: Homophobic
#
# Text: @Ayy Ar  yes bro, today is very enjoy day.ippadiya time irukkum botu  nammudaiya santosattai share pannikkuvom.just konja naltan.appuram neril santikkum botu  piriccu menjuduvom.bro na second trip start panna poren..ippo ninga enakku kai adichi viduringala.na marupadiyum unga kunjiya en vayila vachi kanji varum varai umbi viduren.a you ready ya bro.
# True Label: Normal
# Predicted Label: Normal
#
# Text: mic ha pudingi thala mela adingada avala vanthuta mic thukitu flexed_biceps  oncoming_fist
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Bro oru like podunga
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Priya Priya  un number or insta I'd sollu di
# True Label: Normal
# Predicted Label: Normal
#
# Text: I love all thirunagai Ammaku  folded_hands  loudly_crying_face  folded_hands  loudly_crying_face  folded_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: 4.5+4.5=9 eval oru
# True Label: Homophobic
# Predicted Label: Homophobic
#
# Text: @Bala kumar  wat ur asking.? 1st  olunga kealviya kealunga.
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vekadha
# True Label: Normal
# Predicted Label: Normal
#
# Text: Edhunga tholla thanga mudila. Evangaluku support pandravanga parunga endha vedio ha
# True Label: Transphobic
# Predicted Label: Normal
#
# Text: Vara level pannuga bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Feeling sad super
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vara laval bro keep going on  thumbs_up  thumbs_up  thumbs_up  thumbs_up
# True Label: Normal
# Predicted Label: Normal
#
# Text: Interview yedukkara ponnu konjam ; carefula irunthuko , ponnungaluku ponnungalae paathukaapu illa  face_with_tears_of_joy  beaming_face_with_smiling_eyes  grinning_face_with_sweat  grinning_face_with_sweat
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Nalla ponnala keduthuduva pola
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Ooru enam searkari kartharuku munpaaga aruvarupanadhu
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Nan kekaran... Iva vaaila en poola vita ena...????
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Thirunangai unakku manithargalaga theriyavilaiya oru sila per thavaru seithathurku Ella thirunangai thavaru solvathu  manithargalaga seyal
# True Label: Normal
# Predicted Label: Normal
#
# Text: First Anda Allu ena varthai kettan first podungada.  Ivanga pesuratha mattum eduthu iruga
# True Label: Transphobic
# Predicted Label: Normal
#
# Text: Madam... coste vittu coste mrrg pannavey vetranunga...love mrrg pandra aan,pennukey inga pathukappu I'lla..ithula neenga engala vetringa, thitrunga nu sollitu irukinga.....
# True Label: Normal
# Predicted Label: Normal
#
# Text: Hello bro niraya videos podukanga please
# True Label: Normal
# Predicted Label: Normal
#
# Text: Semma antha akka I love her
# True Label: Normal
# Predicted Label: Normal
#
# Text: Saaathiyaa kodumaikkea suthandhiram keadaikkala innum...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Thank you :)
# True Label: Normal
# Predicted Label: Normal
#
# Text: Sriya sonninga bro.. daiy overa peasathanga antha nilamaikku neenga vantha eanna pannuvinga... nalla karuththu solladiyum paravalla solravangala kelvi keatkama irunga...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Antha akka eppadi othugitanga ninga Prank panuninganu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ithu laam train la saatharanam. Naan laam thoongura maari act panniduven
# True Label: Normal
# Predicted Label: Normal
#
# Text: unga getup layae therithu unga amma appa ungala ponna valakala nu..... athoda velipaadu thaan ithu.... penmai izhantha pengalukku innoru pen mel kadhal varuvathu saathiyama....aana athai yerkamal, antha pennin HARMONAL kuraipattai seri seiya vendum...
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Super Bro Best....
# True Label: Normal
# Predicted Label: Normal
#
# Text: Adi seruppaala.....dont encourage these idiots....
# True Label: Normal
# Predicted Label: Normal
#
# Text: Mudinja kasu kodunga illana illa nu solunga , adha vitutu meala kaivekkadhanu    eliva peasuna avangalukum kovam varadhana seium !!  Nothing more to say  zipper-mouth_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: Dei neenga la yenga irunthu da varinga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Dei iva ava la
# True Label: Normal
# Predicted Label: Normal
#
# Text: Intha numberkku callme
# True Label: Normal
# Predicted Label: Normal
#
# Text: Kojam osaara erunthukko ma
# True Label: Normal
# Predicted Label: Normal
#
# Text: 9:03 Kalangitta pa  , Hats off  clapping_hands  handshake  Thirunangai handshake
# True Label: Normal
# Predicted Label: Normal
#
# Text: Apdina malini yum avanga amma vum sex vechu kaalam  malini avanga appa kooda yum malini sex vechukalam appram moonu per sendhum group sex vechukkalam enna karuma di ithu ithellam oru topic nu kamma veri puducha katteriya interview pannitu irukeenga
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: @Ramya Rami   face_with_raised_eyebrow  face_with_raised_eyebrow  face_with_raised_eyebrow
# True Label: Normal
# Predicted Label: Normal
#
# Text: Waiting Bro.. Oru Like poduga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Evlo paiya  face_with_tears_of_joy  face_with_tears_of_joy
# True Label: Normal
# Predicted Label: Normal
#
# Text: Thalaivaa andha saamy ku endha oru problem varama pathukonga pls folded_hands  folded_hands  folded_hands  folded_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: U r soo sweet sennila
# True Label: Normal
# Predicted Label: Normal
#
# Text: Malini semma bold
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super g ..semaya iruthuchi
# True Label: Normal
# Predicted Label: Normal
#
# Text: Kadavul engala ipdi padachrukaaru. Naangallaam romba lucky..
# True Label: Normal
# Predicted Label: Normal
#
# Text: Dei already ponnu kidaikala idhula idhu veraya daw
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: ana ninga seetakara payalungala supper da
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ayyo SEMA super en Kannu kalagiduchu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Serupadii.. Than dii unaku..
# True Label: Normal
# Predicted Label: Normal
#
# Text: vera level bro nice  face_blowing_a_kiss  love you smiling_face_with_heart-eyes
# True Label: Normal
# Predicted Label: Normal
#
# Text: Anna super share anna...illathavangalukku kudukkurathukku oru nalla manasu venum..athu unga kitta irukku
# True Label: Normal
# Predicted Label: Normal
#
# Text: Eval oru 9 eva namala pathi thappa soltra
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Ungalukku maddum eappadithaan amaithoo
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nalla panriga Anna i like this video Anna  thumbs_up
# True Label: Normal
# Predicted Label: Normal
#
# Text: Gud soul  red_heart
# True Label: Normal
# Predicted Label: Normal
#
# Text: Neenga sathikarathuu night 11.40 pm na pathuirkaa madam in Nelson manikam road la
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nanum matirukken friend oda anba mobile la thappa chat panni  avan friend oda ammata enga vitla ellaru kittaum solli asingama pochu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro romaba thapu bro nalavangala prank panadhinga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ini aanum aanum aanum and pennum pennum friendsa pesina kooda thappa dhan parkka paduvargal.so sad
# True Label: Homophobic
# Predicted Label: Homophobic
#
# Text: Dei mutta payale avangalum unna madhiri oru humanbeing dan manushana manushana madhika kathuko first.....idhae un kuda porandhavalo porandhavono  ipdi  irundha ipdi dan pesuviya ....grow up man
# True Label: Normal
# Predicted Label: Normal
#
# Text: Smart Subash dai loosu na unmaiya that solra
# True Label: Normal
# Predicted Label: Normal
#
# Text: Amazing movie ...Super
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Tamil Medium Pasanga   ok bro I am waiting
# True Label: Normal
# Predicted Label: Normal
#
# Text: endha mirugam uhm rape panadhu ana indha staright nu solitu rape panranga pa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Andha ammavai vanangukiraen thumbs_up
# True Label: Normal
# Predicted Label: Normal
#
# Text: sariya kelivi avalidam kekka villai
# True Label: Normal
# Predicted Label: Normal
#
# Text: GOD BLESS YOU
# True Label: Normal
# Predicted Label: Normal
#
# Text: 5. Best frnds kulla shoulder illada athavida payankarama irukkum..  thappana thaking la irukathu..  jolly ag birthday annaikku nadakarathu think panni paru..
# True Label: Normal
# Predicted Label: Normal
#
# Text: @3.14 : Adangapa ithula kuda sonthathukula than kudupingala ma. :) Ennama ipdi panrengale ma.
# True Label: Normal
# Predicted Label: Normal
#
# Text: Sathiyama Vera level bro OK_hand  thumbs_up
# True Label: Normal
# Predicted Label: Normal
#
# Text: iva Vijay rasikaiya irupalo
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Chinmey vida alaga irukanga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro,vera level activ .. super
# True Label: Normal
# Predicted Label: Normal
#
# Text: Veetoda  R C CHRISTIAN Mapillai  thevaina sollunga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Felt so emotional
# True Label: Normal
# Predicted Label: Normal
#
# Text: Pranesh G video va nala paruga avaga kai vachathu kutha ava eduganu sole irukaru athuku tha intha mathiri pesuthu epdi eduka sola lanu nala paruga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Anna Super Naa Naa Lawrence Anna Fan Na smiling_face_with_heart-eyes  smiling_face_with_heart-eyes  OK_hand
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ada pavigala etha etha video podarathunu vevastha illaya?
# True Label: Normal
# Predicted Label: Normal
#
# Text: Op bro spr best video ever ....... face_blowing_a_kiss
# True Label: Normal
# Predicted Label: Normal
#
# Text: Sent me you nomper plase
# True Label: Normal
# Predicted Label: Normal
#
# Text: Varun Amma accept panra mari Part 2 vantha nalla irukim red_heart  fire
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ena oru nalla manasu ivangalu oru uyir poga kudathu nu nenaikuranga love u ma
# True Label: Normal
# Predicted Label: Normal
#
# Text: Poi saavu da
# True Label: Homophobic
# Predicted Label: Homophobic
#
# Text: i. ss nice but
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vera lvl brw.... heart_suit  heart_suit  heart_suit
# True Label: Normal
# Predicted Label: Normal
#
# Text: Avanga iyalpave Rompa azhaha irukanga.
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Sathish Kumar   face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy
# True Label: Normal
# Predicted Label: Normal
#
# Text: Naadu kevalamana future ah noki poi kondu irruku inrathuku intha karumam pidicha theerpu oru yeduthu kaattu !! Ithuku varalatru sirappu mikathu solarathu avanaavanga thoda naadungi thanatha thaan kaatuthu !!
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Super film sir
# True Label: Normal
# Predicted Label: Normal
#
# Text: Mathavangalukaka manasumathitu oru ponna marriage panni avanga valkaiya kedukrathavida ithu evlo paravala athu avangaloda thanibatta virupam
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Very very good
# True Label: Normal
# Predicted Label: Normal
#
# Text: Enaku udambu silithuruchi
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vera leval natipu vera leval thalaivaa..  clapping_hands  clapping_hands  clapping_hands  clapping_hands  clapping_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Innaikku bublikka pesura visayama ithu biblela Luke 17.28 ippadi last days la nadakum so jesus is coming soon
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: 5:41 daii poda  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing
# True Label: Normal
# Predicted Label: Normal
#
# Text: mine mine apo unga appa kita poi sollu...nenga en hetero sex panringanu...sorry unga appavuku
# True Label: Homophobic
# Predicted Label: Homophobic
#
# Text: Da anda part 2
# True Label: Normal
# Predicted Label: Normal
#
# Text: Antha akkavukku nalla manasu folded_hands  folded_hands  folded_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Romba nandri thalaiva share ku
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super sister  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts
# True Label: Normal
# Predicted Label: Normal
#
# Text: It wont decide your future.
# True Label: Normal
# Predicted Label: Normal
#
# Text: I love your  attitude  face_blowing_a_kiss  face_blowing_a_kiss  face_blowing_a_kiss
# True Label: Normal
# Predicted Label: Normal
#
# Text: Pooo dd loosuuu over pesathaa but CRT pesuu try pannuuu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super tq I miss u thirunangaikal
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nice bro  folded_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Mick ah neetunaley peteru thaan
# True Label: Normal
# Predicted Label: Normal
#
# Text: So sweet  red_heart
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ama bro enna panrathu  downcast_face_with_sweat  downcast_face_with_sweat  downcast_face_with_sweat
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Kalai Arasan  apdina ponna kalyaanam pannaama inoru paiyana kalyaanam pannu... Baadu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Akka ithan ennoda no ungalukku enna help venumnslum le lunga..... 8681954127.... Enna la mudijja uothaviya nan seiven.... Unga mela pavappatu illa.... Enakkum oru freds irundha di piritthiga yasini...... Police.... I love you akka
# True Label: Normal
# Predicted Label: Normal
#
# Text: Shreedhar Shreedhar dei kena punda yara serupala adipa ne first avan ena sona kelu ivanga sathama pesurudhu podra adhuku munadi nadandha yaru da ketinga pundaingala
# True Label: Normal
# Predicted Label: Normal
#
# Text: Always transgender... good human
# True Label: Normal
# Predicted Label: Normal
#
# Text: Dislike potta 744 perum kalaachara kaavalargal...!! grinning_squinting_face  grinning_face_with_sweat  face_with_tears_of_joy
# True Label: Normal
# Predicted Label: Normal
#
# Text: @AB super hero  mudiyala Avanga avanga opinion ah Soldranga Brow....  Idhuku edhuku Asthahfirla Soldringa...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Intha Manasu Thaan da Kadavul...
# True Label: Normal
# Predicted Label: Normal
#
# Text: 3:36 thaali katti illana ringu pottu Kalyana pannalam face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy
# True Label: Normal
# Predicted Label: Normal
#
# Text: Yethuku intha vetti velamparam
# True Label: Normal
# Predicted Label: Transphobic
#
# Text: Pesuna  ivanuka ellarum vittuta mapalaiya nu solla ma poitanuka
# True Label: Normal
# Predicted Label: Normal
#
# Text: vaishali mathesan
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nice, ninga epdi beaution join pannainga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Naanu, ennoda husband uh thirunaggaigalaa erukka sagodharigalukku Respect pannuvo yengalaala Muduja help pannuvo avagalukku,,,,,,, mudujalavu thirunaggai sagodharigalai Respect pannuga please  folded_hands  folded_hands  folded_hands  folded_hands  folded_hands  folded_hands  folded_hands  folded_hands  folded_hands  folded_hands  tulip  tulip  tulip  tulip  tulip  tulip  tulip  tulip  tulip  tulip  white_flower
# True Label: Normal
# Predicted Label: Normal
#
# Text: Cuteaah Tamil pesura Akka ..... Top tackar....
# True Label: Normal
# Predicted Label: Normal
#
# Text: I juz luv ur attitude malini
# True Label: Normal
# Predicted Label: Normal
#
# Text: Hands off you bro  smiling_face_with_heart-eyes  smiling_face_with_heart-eyes  smiling_face_with_heart-eyes  smiling_face_with_heart-eyes yannoda support appomum erukum bro ongaluku ethu conform bro niga pannuga bro aru vanthalum pathukalm face_blowing_a_kiss  face_blowing_a_kiss
# True Label: Normal
# Predicted Label: Normal
#
# Text: nice you  fire  fire  fire  fire  fire
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nanum tha gay anna  two_hearts  heart_with_ribbon  sparkling_heart
# True Label: Normal
# Predicted Label: Normal
#
# Text: I love you gay me Malaysia
# True Label: Normal
# Predicted Label: Normal
#
# Text: Malini Nalla bothi saali  ponnu...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Thaaimai adaiya mudiyavittalum thaaimai ullam ullavargalaga irukirirgal...
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Shahira Banu  nenga tgya
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ellarum thappanavanga illa
# True Label: Normal
# Predicted Label: Normal
#
# Text: enga da 1 bit koda illa
# True Label: Normal
# Predicted Label: Normal
#
# Text: po di thavidiya
# True Label: Normal
# Predicted Label: Normal
#
# Text: I support LGBT people
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nee ennathan ungala nayapaduthi pesalalum.. society ku niggal ellorum Chee thuu tan.. me2..thuu sweat_droplets
# True Label: Homophobic
# Predicted Label: Transphobic
#
# Text: @Maya Mithra  nee nalla docter ah parththittu vanthu varalaaru patti pesu... ithu aarampa nilai than kaaddinal sare aakidum
# True Label: Normal
# Predicted Label: Normal
#
# Text: World health ??? Ena ilukara Ara Kora nayae
# True Label: Normal
# Predicted Label: Normal
#
# Text: karamum ena kandraviyo athellam indiala mukkiyama Tamil nadula Ban paniranum
# True Label: Normal
# Predicted Label: Normal
#
# ...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Mahesh please da enala mudiyala en kita vada daily sagaran
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro part 2 enga bro.....1 year aagum pola neenga movie Mathiri konjam fastta podu bro...
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro pichaikaran prank pannunga onga channel la pannra ellame Vera leval views pothu confirm romba famous aagalam
# True Label: Normal
# Predicted Label: Normal
#
# Text: Varthaivaralay Anna anthaakka great
# True Label: Normal
# Predicted Label: Normal
#
# Text: I am just cried beaming_face_with_smiling_eyes  loudly_crying_face  loudly_crying_face  bro solla varthaikal illa
# True Label: Normal
# Predicted Label: Normal
#
# Text: hi I love you num pathutu utan delete panniru onbthu nalu eattu eaalu rendu eattueattu  rendu. Onbthu munu
# True Label: Normal
# Predicted Label: Normal
#
# Text: @CR. J  u started doing yoga ahh!
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro supar bro sama sapert in thirunangai
# True Label: Normal
# Predicted Label: Normal
#
# Text: JAILA PODANUM ......
# True Label: Normal
# Predicted Label: Transphobic
#
# Text: Feminist gumbala aatha nee face_with_tears_of_joy  face_with_tears_of_joy  face_with_tears_of_joy
# True Label: Normal
# Predicted Label: Normal
#
# Text: Aai apdiya pandra ya
# True Label: Normal
# Predicted Label: Normal
#
# Text: Respect you sis
# True Label: Normal
# Predicted Label: Normal
#
# Text: intha polapuku thuku Matti sagalam ne mudikitu podi lusu
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Climax vera level bro clapping_hands  raising_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Summa sollu bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Adichiko un serupa kalutti neeyea
# True Label: Transphobic
# Predicted Label: Transphobic
#
# Text: Kuttyma Jaya ennada pandrathu ella vetthi
# True Label: Normal
# Predicted Label: Normal
#
# Text: Avangalin kastatha apdiye kaatinga bro...big clap bro....lv u bro... smiling_face_with_open_hands  smiling_face_with_open_hands  smiling_face_with_open_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ajithvishwakumar meenakshisundaram hi
# True Label: Normal
# Predicted Label: Normal
#
# Text: Oruthanuku oruthinu tha kelvi pattu valandhom aana ipo ulagam edha noki poitu irukune therla...   sad_but_relieved_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ungalku thirunangai kolandhaya porandha enna panuvinga?
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Mohamed Ashif  dei nadikkatha da avanga ponnunu theriyatha unakku grimacing_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: Indha video kaga subscribe pandrean
# True Label: Normal
# Predicted Label: Normal
#
# Text: Epada varum sollitu pongada
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super figure action
# True Label: Normal
# Predicted Label: Normal
#
# Text: Wow really super nakalum salem
# True Label: Normal
# Predicted Label: Normal
#
# Text: Anna neega nalla hard work pannrainga kandippa periya screenla Vara all the best
# True Label: Normal
# Predicted Label: Normal
#
# Text: Idhellam oru polappa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Surya Rishu nice
# True Label: Normal
# Predicted Label: Normal
#
# Text: Prank roamba longaa irukku
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ne 1st straight ah naye....neeyum orunal innoru paiyan pinnadi pova
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bangalore la yaryaru irkinga coment la solunga?
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Ayy Ar  hi dear, ninga linenukku varatatarkku karanam,nan etuvum tavaraga pesiyiruntal tayavu seitu ennai mannittu vidungal.iruntalum nan ungal  Mel vaittirukkum pasamum,anbum  unmaiyanatu.nan etum ungala manatai kayapaddutti iruntal  i am very sorry dear.ungalin anbu enakku kidaikka mindum avaludan etirpartu katti kondirukkren.pls reply me.i love you, and i miss you. Take are. Ummmmmmah.
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro kannu kalanga vachuta bro....
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro nega vera level semma
# True Label: Normal
# Predicted Label: Normal
#
# Text: Akka ungala madhiri oruthavangala na en valkaila paathadhey kidaiyadhu neenga romba nalavanga akka neenga unmaiyavey ninga oru ponnu dhan enakku aluga varudhu akka
# True Label: Normal
# Predicted Label: Normal
#
# Text: valarpu seri illa face_with_tears_of_joy  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Vera level bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vera level bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Apdiye ivan prank pannalamnu wait pannuvanam oru tirunangai kaha, udane corrects tirunangai vandhudumam
# True Label: Normal
# Predicted Label: Normal
#
# Text: Nan kadavulla pathutan
# True Label: Normal
# Predicted Label: Normal
#
# Text: tamil medium pasanga da... therida .. thambis
# True Label: Normal
# Predicted Label: Normal
#
# Text: Intha ponnoda Appa Amma sollamataga polla, ivala la interview edukuran parru, avan pinja serrupula adikanum
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Thala enthamari yeadathula kovam romba  varum don't weast ur time 2pearaiyavathu vidama verithanama adinga next yealamea oodi poiruvanga ...na anubavamm patturukea .... yeanga ponalum avagaloda tholla athigamave eruku
# True Label: Normal
# Predicted Label: Normal
#
# Text: 3:57 thala... Neeye.. Ippovo appovo nu irukka...  cat_with_tears_of_joy  cat_with_tears_of_joy  cat_with_tears_of_joy  cat_with_tears_of_joy
# True Label: Normal
# Predicted Label: Homophobic
#
# Text: Avanga than onmaiya na. Manithaikala
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ithumari alungala sumava thali vekuranga. ......
# True Label: Normal
# Predicted Label: Transphobic
#
# Text: vera leavel bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro nalaa panrinkaa bro neraiyaaa pranks panunkaa grinning_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: arun kumar athuvum crct tha nambha aalunghala thirutha mudiyathu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ozhache Saapta idhungaluku life na Enna nu theriyum....
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Ayy Ar  enna machan seiyaringa.
# True Label: Normal
# Predicted Label: Normal
#
# Text: Your dialouge delivery excellent  red_heart  red_heart  red_heart  red_heart
# True Label: Normal
# Predicted Label: Normal
#
# Text: Kadai vechu nadathura middle class people ku theriyum ivanuha paduthura paadu paavam nu ninaipom but idhunga overaaa aadum
# True Label: Transphobic
# Predicted Label: Normal
#
# Text: Ivan ambala potta vesam potturukan ivana pedicji jaila podanum
# True Label: Transphobic
# Predicted Label: Transphobic
#
# Text: io samy 9kitta maatuna summa vituvangala
# True Label: Transphobic
# Predicted Label: Normal
#
# Text: Supper pa nalla iruppinka
# True Label: Normal
# Predicted Label: Normal
#
# Text: They vai ellamai pesathiga ok ethu eyarkai yaana vesayam yaaru onnu pannamudiyadhu yaaraiyum asigama pesathiga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Neenga nadikira mariye illa.... nejama maruna mariye iruku grinning_squinting_face  grinning_squinting_face  grinning_squinting_face .. super..
# True Label: Normal
# Predicted Label: Normal
#
# Text: NAA tha like pana
# True Label: Normal
# Predicted Label: Normal
#
# Text: Enga ponalu Meera Mithun a pathiye pesringaa
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vera leval Thala
# True Label: Normal
# Predicted Label: Normal
#
# Text: Amount vabthuruchu thala semma kan kalankitten nanbaaaaaaaa revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  revolving_hearts  two_hearts  two_hearts  revolving_hearts  two_hearts  revolving_hearts  two_hearts  revolving_hearts  two_hearts  revolving_hearts  two_hearts
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro masss kalakkitinga 10/10, vera level acting nanba.
# True Label: Normal
# Predicted Label: Normal
#
# Text: Dei caste mathi kalyanam pannikavae othukamatranunga... aprm epud homosex ah othupanunga.. sis ne crt tha .. thappunu soltravanunga marurathuku rmba yr agu... aunga aunga bedroom la nadakurathu maatha namma yaru.. their wish.. unga velaya mattu parunga.. apud matha velayatha pappena rape pantrava kola pantravana mathunga  ponga
# True Label: Normal
# Predicted Label: Normal
#
# Text: Vera level acting ya yo  grinning_squinting_face  face_with_tears_of_joy  rolling_on_the_floor_laughing
# True Label: Normal
# Predicted Label: Normal
#
# Text: Lesbian gay  Ivargalai mathipom.Ivargalal yarukkum entha badhipum kidayathu rendu manamum othuponal manathara vazhuthuvom. I love too lesbians and gays.
# True Label: Normal
# Predicted Label: Normal
#
# Text: Acid mutta prank
# True Label: Normal
# Predicted Label: Normal
#
# Text: +Ashuu Sayyed .....yalla nalladhuku tha friend. don't feel.
# True Label: Normal
# Predicted Label: Normal
#
# Text: @Gpmuthu Official  ennachu bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ninga inta nombarukku watsapp panna mudiyuma
# True Label: Normal
# Predicted Label: Normal
#
# Text: Thala vali ipa woraiyur layum
# True Label: Normal
# Predicted Label: Normal
#
# Text: Avanga yarum ungala kastapaduthala .. Ippavum miss malini  solradhu.. Thanimanitha suganthiram. Na ena sapdanum enna dress podanumnu neenga mudivu panna mudiyathu... Yarukum thontharavu illama avanga vazhkaiya avanga vazhurangaa....
# True Label: Normal
# Predicted Label: Normal
#
# Text: Manikattu varai . Its means hand glow  area vara ulla vitten  dude
# True Label: Normal
# Predicted Label: Normal
#
# Text: Antha akka semmmmma
# True Label: Normal
# Predicted Label: Normal
#
# Text: @vijay visvasi  ethukku unakku kodukanum..nee sethuthola
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Wow semma cute ah irukanga yendha padathula nadichurukanga
# True Label: Normal
# Predicted Label: Normal
#
# Text: jeeva nandan ungalai poruthavai Ellam Kamam than Illa brilliant command
# True Label: Normal
# Predicted Label: Normal
#
# Text: A great tamil wonder women
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ok. Iloveyou bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Daeee machaaaa superrrrrr daa vera level ini unaku ellame success tha machaaaa ennoda support unaku eppovume irukum da keep it up machaaaa this is manimaran da
# True Label: Normal
# Predicted Label: Normal
#
# Text: Idhu mutrilum kevalamanadhu.. Iyarkaiku ediranadu.. Idhu naatukum en ulagathukume kedu.
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: Great job ur rocks
# True Label: Normal
# Predicted Label: Normal
#
# Text: I like u vj anna
# True Label: Normal
# Predicted Label: Normal
#
# Text: correct Abdul bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Endi thevidiya punda sunni... Unga amma kuda poiyu padu
# True Label: Homophobic
# Predicted Label: Transphobic
#
# Text: Thaaaaa vera level daaaaaa  thumbs_up  thumbs_up  thumbs_up  thumbs_up  neee nalla iruppa daaa... thambi.... semma acting.. nee azhratha parthu en kannu automatic kalangirichi da.... vera level.... koodaiya viraivil... 1m subscribe thaandi indha chennel valarum da... open_hands  open_hands  open_hands  open_hands
# True Label: Normal
# Predicted Label: Normal
#
# Text: Semma thalaiva vaipe Ella.....
# True Label: Normal
# Predicted Label: Normal
#
# Text: @chandra lekha  yei kena punda inga public la unna maathiri avuthu kamika enaku pudikala unnoda WhatsApp number kudu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Kaaasu kuduthu nadikregale da...... thufff
# True Label: Normal
# Predicted Label: Normal
#
# Text: I love you thiru nangai. Super bro
# True Label: Normal
# Predicted Label: Normal
#
# Text: Super  nanba
# True Label: Normal
# Predicted Label: Normal
#
# Text: Manivel  thumbs_up  but alugaya varuthu suparpa thumbs_up
# True Label: Normal
# Predicted Label: Normal
#
# Text: Prabhu Prabhu  avanga kannadi potta unaku ena.. Pakka mudiyalana Apadi orama ponga....life na enanu konjam sollunga...
# True Label: Normal
# Predicted Label: Normal
#
# Text: avar avar unarvuku mathipu alika vendum....
# True Label: Normal
# Predicted Label: Normal
#
# Text: Bro.  Epadi bro.  Semma bro.  Good acting
# True Label: Normal
# Predicted Label: Normal
#
# Text: We r waiting
# True Label: Normal
# Predicted Label: Normal
#
# Text: who said that homosexuality is nature nu athu historical people  kalapokuku etha mathiri mathikitanga, historical people ta nallatha irundha eduthukanum, ketta than irundha avoid pannurathu nallathu. En நாய் kuda appadi homosex panuratuu illaye. En kaa, culture lam thevai Illa but behavior and mankind is more important to humans. Uneducated akkaku kuda therijiirukuthu ithu thapunu. Educated aana ungalukum avungaluku Enna vidiyasam. Athuku than god create pannumbodu men and women na padaicharu. Kala pokula nama valithavariporom.
# True Label: Normal
# Predicted Label: Normal
#
# Text: Enna porutha varaum ethu ok than periya ammalanga 1mulan sunniya vatchu Chennai ponnungala vettayadaranga ethu paravayillaya. LGBT eruntha thappukal kuraum
# True Label: Homophobic
# Predicted Label: Normal
#
# Text: @Mani Shankar Iyer  really nambra maari ye illa.... But padam vera level feel
# True Label: Normal
# Predicted Label: Normal
#
# Text: BONDA vaayan with beautiful girl... I  rolling_on_the_floor_laughing  rolling_on_the_floor_laughing  grinning_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: Empa ashiq oru channel la dhan un tholla thangala na indha channel layum idhey velai pathu kadupu ethriye ya nee
# True Label: Normal
# Predicted Label: Normal
#
# Text: பிரகாஷ் தேவராஜ் ada pooya yov...puriyum padi solluya...summa poya yov..
# True Label: Normal
# Predicted Label: Normal
#
# Text: Seriously na pathale payapduva ivagalala ana intha video avaga katra paasam kan kalanga vechiduchu loudly_crying_face  loudly_crying_face  loudly_crying_face
# True Label: Normal
# Predicted Label: Normal
#
# Text: Jenkins-Tq friend :)
# True Label: Normal
# Predicted Label: Normal
#
# Text: So  very  sad
# True Label: Normal
# Predicted Label: Normal
#
# Text: kattupaadu pirakradhula enna thappu iruku
# True Label: Homophobic
# Predicted Label: Homophobic
#
# Text: naa niraya edathula paathurukken,  ivanga paisa Kettu naama kodukkalanaam saabam vidarapola pesittu thittitu poranga,,    yaaralaume ekuthu kekkamudila bcoz thirunangaiya irukkanganga,  then avanga romba Asingama kocha vaarthaikala use pandranga,,
# True Label: Normal
# Predicted Label: Normal
#
# Text: Iyo ennaku aluvaramathiri aaiduchu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Mannikavum Enna Thampi nu solla ungaluku athigaram ila
# True Label: Normal
# Predicted Label: Normal
#
# Text: True Blood love
# True Label: Normal
# Predicted Label: Normal
#
# Text: Athuku nega homo va iruthatha therium mr yogi. Athuvaikum nega soldrathulam thanila ealuthuramari tha
# True Label: Normal
# Predicted Label: Normal
#
# Text: Thirunangai na romba mosamana vanganu nenaichan anna ana athu thapunu ippa than theriyuthu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Semma Mass  smiling_face_with_hearts
# True Label: Normal
# Predicted Label: Normal
#
# Text: Excellent awareness video  thumbs_up  thumbs_up  thumbs_up  thumbs_up
# True Label: Normal
# Predicted Label: Normal
#
# Text: Appan magalai karpazhikkumpothu, maamiyaar marumagan pirantha kuzhanthaiyai karpazhikkumpothu  maamanaar marumagal uravu kanavanukku manavi dhrogam manaivikki kanvan dhrogam thagaatha uravu vaithu kollumbothu ungalukku ulagam azhiyapogirathu enru theriya villayaa sagotharare!!!!!!!!!!!!
# True Label: Normal
# Predicted Label: Normal
#
# Text: Akka pls hi sollunga
# True Label: Normal
# Predicted Label: Normal
#
# Text: rompa azhagana devathai mathiri irukinga neenga.
# True Label: Normal
# Predicted Label: Normal
#
# Text: Ore aalu avan ellaathaium ethirkiraan, paravaa illai,
# True Label: Normal
# Predicted Label: Normal
#
# Text: Serupu.. Otha sex na enanu therichikitu pesuda badu
# True Label: Normal
# Predicted Label: Normal
#
# Text: Mein ha beach la idhunga thola thangave mudiyala... respect ha kuduikka kudathu..ithungala pavame pakka koodadhu
# True Label: Normal
# Predicted Label: Normal
